# %% [markdown]
# <a href="https://colab.research.google.com/github/Joanachoong/Externship/blob/main/Glassdoor_cleaned_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# call the fucntion to clean data
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import string
from nltk.corpus import stopwords

def clean_text(text):
    # Convert to lowercase and remove punctuation
    if pd.isnull(text):
      return ' '
    text = text.lower().translate(str.maketrans('', '', string.punctuation))

    # Split into words
    words = text.split()

    # Remove stopwords
    filtered = [word for word in words if word not in stopwords.words('english')]

    # Join back into a single string
    return ' '.join(filtered)

# %% [markdown]
# summary,
# advice_to_management,
# review_pros,
# review_cons,

# %%
# load glass door csv folder
# call the file
import pandas as pd

from google.colab import drive
data = pd.read_csv('glassdoor_cleaned_v2.csv')

# original data
print(data['summary'])
print(data['advice_to_management'])
print(data['review_pros'])
print(data['review_cons'])
# Out:
# 0                                                 Amazon
# 1                                                   Good
# 2                                        Good experience
# 3                                                   Dhdh
# 4                                          Good Pay rate
#                              ...
# 121                                              nothign
# 122                                              General
# 123                                               Review
# 124                           Nepotism and Ethnocentrism
# 125    Continuous work without sitting, almost all lo...
# Name: summary, Length: 126, dtype: object
# 0                                     don’t micro manage
# 1             Remove all attitude manager from warehouse
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 121                                                  NaN
# 122                                                  NaN
# 123    Treat associates with respect and dignity. Fos...
# 124                                                  NaN
# 125                                                  NaN
# Name: advice_to_management, Length: 126, dtype: object
# 0      not interactive \ncan leave or take off whenev...
# 1                          good and easy work enviorment
# 2                              help to grow , good pay ,
# 3                        Plenty of work\nMeet new people
# 4      Good Holiday pay \nAdditional benefits for per...
#                              ...
# 121                        good pay and nice shift hours
# 122              Flexible working schedules and good pay
# 123    Good benefits.\nValuable working experience.\n...
# 124         PTO and task are easy to lean pays the bills
# 125    Pay and Benefits they provide like maternity, ...
# Name: review_pros, Length: 126, dtype: object
# 0          inhumane \ndraining physically &amp; mentally
# 1      Sticks rules and completing targets any how, o...
# 2      limited opportunities for advancement,No clear...
# 3                     Tough on the body\nLabor intensive
# 4                Not hiring permanent employees directly
#                              ...
# 121            politics and partiality play a major role
# 122    Extremely physical. Employees treated as machi...
# 123    Poor management support.\nLack of understandin...
# 124    Almost 99% of workers are Indian/South Asian T...
# 125    Poor Work Conditions and Management Support: U...
# Name: review_cons, Length: 126, dtype: object

# %%
#clean the data by caliing the function
data['cleaned_summary']=data['summary'].apply(clean_text)
data['cleaned_advice']=data['advice_to_management'].apply(clean_text)
data['cleaned_reviewPros']=data['review_pros'].apply(clean_text)
data['cleaned_reviewCons']=data['review_cons'].apply(clean_text)

#check the result
print(data['summary'])
print(data['advice_to_management'])
print(data['review_pros'])
print(data['review_cons'])
# Out:
# 0                                                 Amazon
# 1                                                   Good
# 2                                        Good experience
# 3                                                   Dhdh
# 4                                          Good Pay rate
#                              ...
# 121                                              nothign
# 122                                              General
# 123                                               Review
# 124                           Nepotism and Ethnocentrism
# 125    Continuous work without sitting, almost all lo...
# Name: summary, Length: 126, dtype: object
# 0                                     don’t micro manage
# 1             Remove all attitude manager from warehouse
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 121                                                  NaN
# 122                                                  NaN
# 123    Treat associates with respect and dignity. Fos...
# 124                                                  NaN
# 125                                                  NaN
# Name: advice_to_management, Length: 126, dtype: object
# 0      not interactive \ncan leave or take off whenev...
# 1                          good and easy work enviorment
# 2                              help to grow , good pay ,
# 3                        Plenty of work\nMeet new people
# 4      Good Holiday pay \nAdditional benefits for per...
#                              ...
# 121                        good pay and nice shift hours
# 122              Flexible working schedules and good pay
# 123    Good benefits.\nValuable working experience.\n...
# 124         PTO and task are easy to lean pays the bills
# 125    Pay and Benefits they provide like maternity, ...
# Name: review_pros, Length: 126, dtype: object
# 0          inhumane \ndraining physically &amp; mentally
# 1      Sticks rules and completing targets any how, o...
# 2      limited opportunities for advancement,No clear...
# 3                     Tough on the body\nLabor intensive
# 4                Not hiring permanent employees directly
#                              ...
# 121            politics and partiality play a major role
# 122    Extremely physical. Employees treated as machi...
# 123    Poor management support.\nLack of understandin...
# 124    Almost 99% of workers are Indian/South Asian T...
# 125    Poor Work Conditions and Management Support: U...
# Name: review_cons, Length: 126, dtype: object

# %%
# import the data
data.to_csv('glassdoor_cleaned_text.csv', index=False)
