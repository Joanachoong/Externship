# %% [markdown]
# <a href="https://colab.research.google.com/github/Joanachoong/Externship/blob/main/Externship_Amazon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##GLASS DOOR DATATSET AND YOUTUBE DATASET
#spot patterns in feedback, distinguish signal from noise

# %%
import pandas as pd

from google.colab import drive
data = pd.read_csv('glassdoor_review.csv')

# Preview the data
print(data.head())

# Get info about the columns
print(data.info())

# Check number of rows and columns
print(data.shape)

# Get statistical summary of numeric columns
print(data.describe())
# Out:
#    Unfair Workplace Practices and Lack of Growth Opportunities and Poor Work Conditions and Management Support:  \
# 0                                                  1
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  5
#
#                 rating_date  count_helpful  count_unhelpful  employee_length  \
# 0  2025-06-03T00:00:00.000Z              0                0                0
# 1  2025-05-29T00:00:00.000Z              0                0                1
# 2  2025-05-28T00:00:00.000Z              0                0                1
# 3  2025-05-26T00:00:00.000Z              0                0                2
# 4  2025-05-23T00:00:00.000Z              0                0                0
#
#   employee_status                       employee_type  flag_covid  \
# ...

# %%
from google.colab import files
uploaded = files.upload()

#.head() shows the first five rows of the dataset,
#.info() provides details about the DataFrame, including the number of non-null entries, data types,
# and memory usage, which are helpful for assessing the data's quality and structure.

# Inspect the first few rows of the DataFrame
print("First five rows of the dataset:")
print(data.head())

# Get a summary of the DataFrame
print("\nDataFrame summary:")
print(data.info())
# Out:
#      <input type="file" id="files-bf025fc4-3978-4752-8997-d5a520618144" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf025fc4-3978-4752-8997-d5a520618144">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Remove Unnecessary Columns

# %%
data['company_name'].value_counts()
# Out:
# company_name
# Amazon Fulfillment Center    125
# Amazin Fullfilment Center      1
# Name: count, dtype: int64

# %%
## remove value
data= data.drop(columns=['count_helpful',
                         'count_unhelpful',
                         'flags_recommend_frend',
                         'flags_business_outlook',
                         'company_name',
                         'rating_culture_values',
                         'rating_diversity_inclusion',






                         ]) # Adjust based on your findings
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3792157384.py in <cell line: 0>()
#       1 ## remove value
# ----> 2 data= data.drop(columns=['count_helpful',
#       3                          'count_unhelpful',
#       4                          'flags_recommend_frend',
#       5                          'flags_business_outlook',
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
# ...

# %%
# Check how many values are missing in each column
data.isnull().sum().sort_values(ascending=False)

# See how many unique values each column has
data.nunique().sort_values()

# Drop rows where the main review text is missing
data = data.dropna(subset=['summary'])

# Remove any exact duplicate rows
data = data.drop_duplicates()

print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126 entries, 0 to 126
# Data columns (total 19 columns):
#  #   Column                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                        --------------  -----
#  0   Unfair Workplace Practices and Lack of Growth Opportunities and Poor Work Conditions and Management Support:  126 non-null    int64
#  1   rating_date                                                                                                   126 non-null    object
#  2   employee_length                                                                                               126 non-null    int64
#  3   employee_status                                                                                               124 non-null    object
# ...

# %%
data.to_csv('glassdoor_cleaned.csv', index=False)
